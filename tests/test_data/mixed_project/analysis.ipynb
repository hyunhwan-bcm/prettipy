# %% [markdown]
# # Data Analysis Notebook
#
# This notebook demonstrates using functions from utils.py

# %%
# Import utilities from utils module
from utils import calculate_sum, calculate_product, Calculator

# %%
# Perform some calculations
x = calculate_sum(100, 200)
y = calculate_product(10, 20)
print(f"Sum: {x}, Product: {y}")

# %%
# Use the Calculator class
calculator = Calculator()
result1 = calculator.add(50, 75)
result2 = calculator.multiply(8, 9)
print(f"Calculator results: {result1}, {result2}")

# %% [markdown]
# ## Data Processing
#
# Process some sample data

# %%
# Sample data
data = [1, 2, 3, 4, 5]

# Process each element
for i, value in enumerate(data):
    squared = calculate_product(value, value)
    print(f"data[{i}]^2 = {squared}")
