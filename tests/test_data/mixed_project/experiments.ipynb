# %% [markdown]
# # Experiments Notebook
#
# This notebook uses functions from both main.py and utils.py

# %%
# Import from main module
from main import process_data
from utils import Calculator

# %%
# Use process_data function from main.py
test_data = [10, 20, 30, 40, 50]
results = process_data(test_data)
print(f"Results: {results}")

# %% [markdown]
# ## Run experiments with Calculator

# %%
# Create calculator and run experiments
calc = Calculator()

# Experiment 1
calc.add(100, 200)
calc.multiply(5, 10)

# Experiment 2
calc.add(25, 75)
calc.multiply(12, 3)

print("Experiment history:")
for entry in calc.history:
    print(f"  - {entry}")

# %%
# Define a helper function that uses process_data
def analyze_dataset(dataset):
    """Analyze a dataset using main.process_data."""
    result = process_data(dataset)
    print(f"Dataset analysis complete: {result}")
    return result

analyze_dataset([5, 10, 15, 20])
